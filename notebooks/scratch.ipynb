# %%
from inv_plts.data.utils import load_hf_dataset

combined_dataset = load_hf_dataset(sampling_type='full', leaf_view='dorsal', cache_dir="/local/scratch/carlyn.1/hf_dataset_cache")

# %%
for row in combined_dataset:
    print(row)
    break

combined_dataset
